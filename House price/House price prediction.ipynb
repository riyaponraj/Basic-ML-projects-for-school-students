# %% [markdown]
# # IMPORT REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pandas: provides high-performance data manipulation
#
# Numpy: perform various mathematical operations on arrays - trigonometry, statistics

# %% [markdown]
# # Data Exploration

# %%
df = pd.read_csv(r'C:\Users\riyap\Downloads\archive (2)\melb_data.csv') # replace the path of file inside quotes

# %% [markdown]
# Change the url written within the quotes with the raw data link

# %%
url= 'https://raw.githubusercontent.com/riyaponraj/Basic-ML-projects-for-school-students/main/House%20price/melb_data.csv?token=GHSAT0AAAAAAB2PG5TLCHH6TTV6EPLA2YHKY4A4GNA'
df = pd.read_csv(url)

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df1 = pd.DataFrame(df.head(1000)) #you can change the count by replacing 1000
df1
# Out:
#          Suburb           Address  Rooms Type      Price Method    SellerG  \
# 0    Abbotsford      85 Turner St      2    h  1480000.0      S     Biggin
# 1    Abbotsford   25 Bloomburg St      2    h  1035000.0      S     Biggin
# 2    Abbotsford      5 Charles St      3    h  1465000.0     SP     Biggin
# 3    Abbotsford  40 Federation La      3    h   850000.0     PI     Biggin
# 4    Abbotsford       55a Park St      4    h  1600000.0     VB     Nelson
# ..          ...               ...    ...  ...        ...    ...        ...
# 995    Box Hill    6 Archibald St      3    h  4000000.0     VB  Lindellas
# 996    Box Hill        19 Kent Rd      3    h   928000.0      S  Lindellas
# 997    Box Hill  2/20 Simpsons Rd      2    u   761000.0      S   Marshall
# 998    Box Hill     3/8 Ashted Rd      2    u   636000.0      S     Philip
# 999    Box Hill         6 Bass St      4    h  1625000.0      S       Noel
#
#            Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df1.describe()   #gives statiscal description
# Out:
#              Rooms         Price     Distance     Postcode    Bedroom2  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.00000
# mean      3.093000  1.247068e+06    10.168800  3115.248000     3.04100
# std       0.960872  6.843499e+05     3.485564    61.111071     0.96967
# min       1.000000  2.800000e+05     2.500000  3018.000000     0.00000
# 25%       2.000000  7.607500e+05     6.550000  3042.000000     2.00000
# 50%       3.000000  1.100000e+06    10.500000  3104.000000     3.00000
# 75%       4.000000  1.529625e+06    13.500000  3165.000000     4.00000
# max       8.000000  5.525000e+06    13.900000  3206.000000     9.00000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  1000.000000  1000.000000   1000.000000    562.000000   627.000000
# mean      1.642000     1.732000    533.443000    163.921708  1963.411483
# std       0.787691     1.000588   2384.080755    101.511646    35.777352
# ...

# %% [markdown]
# # Check for missing values

# %%
df1.isnull().sum()
# Out:
# Suburb             0
# Address            0
# Rooms              0
# Type               0
# Price              0
# Method             0
# SellerG            0
# Date               0
# Distance           0
# Postcode           0
# Bedroom2           0
# Bathroom           0
# Car                0
# Landsize           0
# BuildingArea     438
# YearBuilt        373
# CouncilArea        0
# Lattitude          0
# Longtitude         0
# Regionname         0
# Propertycount      0
# dtype: int64

# %%
df1 = df1.dropna(axis=0) # dropna drops missing values (think of na as "not available")

# %%
df1.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# # View the features available

# %%
df1.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# # Choosing prediction value

# %%
y = df1['Price']

# %%
y
# Out:
# 1      1035000.0
# 2      1465000.0
# 4      1600000.0
# 6      1876000.0
# 7      1636000.0
#          ...
# 991     775000.0
# 993    1670000.0
# 995    4000000.0
# 996     928000.0
# 998     636000.0
# Name: Price, Length: 542, dtype: float64

# %% [markdown]
# # Choosing required features

# %%
features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %%
x = df1[features]

# %%
x.head()
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954

# %% [markdown]
# # BUILDING YOUR MODEL

# %%
from sklearn.tree import DecisionTreeRegressor

# Define model.
#Specify a number for random_state to ensure same results each run
model = DecisionTreeRegressor(random_state=1)

# Fit model
model.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print("Making predictions for the following 5 houses:")
print(x.head())
print("The predictions are")
print(model.predict(x.head()))
# Out:
# Making predictions for the following 5 houses:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1      2       1.0     156.0   -37.8079    144.9934
# 2      3       2.0     134.0   -37.8093    144.9944
# 4      4       1.0     120.0   -37.8072    144.9941
# 6      3       2.0     245.0   -37.8024    144.9993
# 7      2       1.0     256.0   -37.8060    144.9954
# The predictions are
# [1035000. 1465000. 1600000. 1876000. 1636000.]

# %% [markdown]
# Verify your results

# %%
y.head()
# Out:
# 1    1035000.0
# 2    1465000.0
# 4    1600000.0
# 6    1876000.0
# 7    1636000.0
# Name: Price, dtype: float64
